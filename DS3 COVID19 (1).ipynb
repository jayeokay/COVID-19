# %% [markdown]
# CVS raw data

# %% [markdown]
# see current working directory

# %%
pwd
# Out:
# '/Users/xpeng'

# %% [markdown]
# changing directory

# %%
cd downloads/
# Out:
# /Users/xpeng/Downloads

# %%
import pandas as pd

# %%
Comorbidity_data = pd.read_csv('Conditions_contributing_to_deaths_involving_coronavirus_disease_2019__COVID-19___by_age_group_and_state__United_States..csv')

# %%
Comorbidity_data
# Out:
#        Data as of  Start Week    End Week State       Condition Group  \
# 0      11/04/2020  02/01/2020  10/31/2020    US  Respiratory diseases
# 1      11/04/2020  02/01/2020  10/31/2020    US  Respiratory diseases
# 2      11/04/2020  02/01/2020  10/31/2020    US  Respiratory diseases
# 3      11/04/2020  02/01/2020  10/31/2020    US  Respiratory diseases
# 4      11/04/2020  02/01/2020  10/31/2020    US  Respiratory diseases
# ...           ...         ...         ...   ...                   ...
# 12325  11/04/2020  02/01/2020  10/31/2020    PR              COVID-19
# 12326  11/04/2020  02/01/2020  10/31/2020    PR              COVID-19
# 12327  11/04/2020  02/01/2020  10/31/2020    PR              COVID-19
# 12328  11/04/2020  02/01/2020  10/31/2020    PR              COVID-19
# 12329  11/04/2020  02/01/2020  10/31/2020    PR              COVID-19
#
#                      Condition ICD10_codes   Age Group  \
# 0      Influenza and pneumonia     J09-J18        0-24
# 1      Influenza and pneumonia     J09-J18       25-34
# 2      Influenza and pneumonia     J09-J18       35-44
# 3      Influenza and pneumonia     J09-J18       45-54
# 4      Influenza and pneumonia     J09-J18       55-64
# ...                        ...         ...         ...
# 12325                 COVID-19        U071       65-74
# 12326                 COVID-19        U071       75-84
# 12327                 COVID-19        U071         85+
# 12328                 COVID-19        U071  Not stated
# 12329                 COVID-19        U071    All Ages
#
#        Number of COVID-19 Deaths Flag
# 0                          160.0  NaN
# 1                          764.0  NaN
# 2                         1951.0  NaN
# 3                         5526.0  NaN
# 4                        13332.0  NaN
# ...                          ...  ...
# 12325                      193.0  NaN
# 12326                      202.0  NaN
# 12327                      147.0  NaN
# 12328                        0.0  NaN
# 12329                      744.0  NaN
#
# [12330 rows x 10 columns]

# %%
Comorbidity_data.sort_values(by = 'Condition')
US = Comorbidity_data.loc[(Comorbidity_data['State']=='CA') | (Comorbidity_data['State']=='CO')
                         | (Comorbidity_data['State']=='CT')| (Comorbidity_data['State']=='GA')
                          | (Comorbidity_data['State']=='MD')| (Comorbidity_data['State']=='MN')
                          | (Comorbidity_data['State']=='NM')| (Comorbidity_data['State']=='NY')
                          | (Comorbidity_data['State']=='OR')| (Comorbidity_data['State']=='TN')
                    
                         ]
respiratory = US.loc[US['Condition Group'] == 'Respiratory diseases']
respiratory_all = respiratory.loc[respiratory['Age Group'] == 'All Ages']
respiratory_all = respiratory_all.reset_index()
respiratory_all
# Out:
#     index  Data as of  Start Week    End Week State       Condition Group  \
# 0    1149  11/04/2020  02/01/2020  10/31/2020    CA  Respiratory diseases
# 1    1159  11/04/2020  02/01/2020  10/31/2020    CA  Respiratory diseases
# 2    1169  11/04/2020  02/01/2020  10/31/2020    CA  Respiratory diseases
# 3    1179  11/04/2020  02/01/2020  10/31/2020    CA  Respiratory diseases
# 4    1189  11/04/2020  02/01/2020  10/31/2020    CA  Respiratory diseases
# 5    1199  11/04/2020  02/01/2020  10/31/2020    CA  Respiratory diseases
# 6    1379  11/04/2020  02/01/2020  10/31/2020    CO  Respiratory diseases
# 7    1389  11/04/2020  02/01/2020  10/31/2020    CO  Respiratory diseases
# 8    1399  11/04/2020  02/01/2020  10/31/2020    CO  Respiratory diseases
# 9    1409  11/04/2020  02/01/2020  10/31/2020    CO  Respiratory diseases
# 10   1419  11/04/2020  02/01/2020  10/31/2020    CO  Respiratory diseases
# 11   1429  11/04/2020  02/01/2020  10/31/2020    CO  Respiratory diseases
# 12   1609  11/04/2020  02/01/2020  10/31/2020    CT  Respiratory diseases
# 13   1619  11/04/2020  02/01/2020  10/31/2020    CT  Respiratory diseases
# 14   1629  11/04/2020  02/01/2020  10/31/2020    CT  Respiratory diseases
# 15   1639  11/04/2020  02/01/2020  10/31/2020    CT  Respiratory diseases
# 16   1649  11/04/2020  02/01/2020  10/31/2020    CT  Respiratory diseases
# 17   1659  11/04/2020  02/01/2020  10/31/2020    CT  Respiratory diseases
# 18   2509  11/04/2020  02/01/2020  10/31/2020    GA  Respiratory diseases
# 19   2519  11/04/2020  02/01/2020  10/31/2020    GA  Respiratory diseases
# 20   2529  11/04/2020  02/01/2020  10/31/2020    GA  Respiratory diseases
# 21   2539  11/04/2020  02/01/2020  10/31/2020    GA  Respiratory diseases
# 22   2549  11/04/2020  02/01/2020  10/31/2020    GA  Respiratory diseases
# 23   2559  11/04/2020  02/01/2020  10/31/2020    GA  Respiratory diseases
# 24   4809  11/04/2020  02/01/2020  10/31/2020    MD  Respiratory diseases
# 25   4819  11/04/2020  02/01/2020  10/31/2020    MD  Respiratory diseases
# 26   4829  11/04/2020  02/01/2020  10/31/2020    MD  Respiratory diseases
# 27   4839  11/04/2020  02/01/2020  10/31/2020    MD  Respiratory diseases
# 28   4849  11/04/2020  02/01/2020  10/31/2020    MD  Respiratory diseases
# 29   4859  11/04/2020  02/01/2020  10/31/2020    MD  Respiratory diseases
# 30   5499  11/04/2020  02/01/2020  10/31/2020    MN  Respiratory diseases
# 31   5509  11/04/2020  02/01/2020  10/31/2020    MN  Respiratory diseases
# 32   5519  11/04/2020  02/01/2020  10/31/2020    MN  Respiratory diseases
# 33   5529  11/04/2020  02/01/2020  10/31/2020    MN  Respiratory diseases
# 34   5539  11/04/2020  02/01/2020  10/31/2020    MN  Respiratory diseases
# 35   5549  11/04/2020  02/01/2020  10/31/2020    MN  Respiratory diseases
# 36   7339  11/04/2020  02/01/2020  10/31/2020    NM  Respiratory diseases
# 37   7349  11/04/2020  02/01/2020  10/31/2020    NM  Respiratory diseases
# 38   7359  11/04/2020  02/01/2020  10/31/2020    NM  Respiratory diseases
# 39   7369  11/04/2020  02/01/2020  10/31/2020    NM  Respiratory diseases
# 40   7379  11/04/2020  02/01/2020  10/31/2020    NM  Respiratory diseases
# 41   7389  11/04/2020  02/01/2020  10/31/2020    NM  Respiratory diseases
# 42   7569  11/04/2020  02/01/2020  10/31/2020    NY  Respiratory diseases
# 43   7579  11/04/2020  02/01/2020  10/31/2020    NY  Respiratory diseases
# 44   7589  11/04/2020  02/01/2020  10/31/2020    NY  Respiratory diseases
# 45   7599  11/04/2020  02/01/2020  10/31/2020    NY  Respiratory diseases
# 46   7609  11/04/2020  02/01/2020  10/31/2020    NY  Respiratory diseases
# 47   7619  11/04/2020  02/01/2020  10/31/2020    NY  Respiratory diseases
# 48   8719  11/04/2020  02/01/2020  10/31/2020    OR  Respiratory diseases
# 49   8729  11/04/2020  02/01/2020  10/31/2020    OR  Respiratory diseases
# 50   8739  11/04/2020  02/01/2020  10/31/2020    OR  Respiratory diseases
# 51   8749  11/04/2020  02/01/2020  10/31/2020    OR  Respiratory diseases
# 52   8759  11/04/2020  02/01/2020  10/31/2020    OR  Respiratory diseases
# 53   8769  11/04/2020  02/01/2020  10/31/2020    OR  Respiratory diseases
# 54   9869  11/04/2020  02/01/2020  10/31/2020    TN  Respiratory diseases
# 55   9879  11/04/2020  02/01/2020  10/31/2020    TN  Respiratory diseases
# 56   9889  11/04/2020  02/01/2020  10/31/2020    TN  Respiratory diseases
# 57   9899  11/04/2020  02/01/2020  10/31/2020    TN  Respiratory diseases
# 58   9909  11/04/2020  02/01/2020  10/31/2020    TN  Respiratory diseases
# 59   9919  11/04/2020  02/01/2020  10/31/2020    TN  Respiratory diseases
#
#                                    Condition  \
# 0                    Influenza and pneumonia
# 1         Chronic lower respiratory diseases
# 2        Adult respiratory distress syndrome
# 3                        Respiratory failure
# 4                         Respiratory arrest
# 5   Other diseases of the respiratory system
# 6                    Influenza and pneumonia
# 7         Chronic lower respiratory diseases
# 8        Adult respiratory distress syndrome
# 9                        Respiratory failure
# 10                        Respiratory arrest
# 11  Other diseases of the respiratory system
# 12                   Influenza and pneumonia
# 13        Chronic lower respiratory diseases
# 14       Adult respiratory distress syndrome
# 15                       Respiratory failure
# 16                        Respiratory arrest
# 17  Other diseases of the respiratory system
# 18                   Influenza and pneumonia
# 19        Chronic lower respiratory diseases
# 20       Adult respiratory distress syndrome
# 21                       Respiratory failure
# 22                        Respiratory arrest
# 23  Other diseases of the respiratory system
# 24                   Influenza and pneumonia
# 25        Chronic lower respiratory diseases
# 26       Adult respiratory distress syndrome
# 27                       Respiratory failure
# 28                        Respiratory arrest
# 29  Other diseases of the respiratory system
# 30                   Influenza and pneumonia
# 31        Chronic lower respiratory diseases
# 32       Adult respiratory distress syndrome
# 33                       Respiratory failure
# 34                        Respiratory arrest
# 35  Other diseases of the respiratory system
# 36                   Influenza and pneumonia
# 37        Chronic lower respiratory diseases
# 38       Adult respiratory distress syndrome
# 39                       Respiratory failure
# 40                        Respiratory arrest
# 41  Other diseases of the respiratory system
# 42                   Influenza and pneumonia
# 43        Chronic lower respiratory diseases
# 44       Adult respiratory distress syndrome
# 45                       Respiratory failure
# 46                        Respiratory arrest
# 47  Other diseases of the respiratory system
# 48                   Influenza and pneumonia
# 49        Chronic lower respiratory diseases
# 50       Adult respiratory distress syndrome
# 51                       Respiratory failure
# 52                        Respiratory arrest
# 53  Other diseases of the respiratory system
# 54                   Influenza and pneumonia
# 55        Chronic lower respiratory diseases
# 56       Adult respiratory distress syndrome
# 57                       Respiratory failure
# 58                        Respiratory arrest
# 59  Other diseases of the respiratory system
#
#                                           ICD10_codes Age Group  \
# 0                                             J09-J18  All Ages
# 1                                             J40-J47  All Ages
# 2                                                 J80  All Ages
# 3                                                 J96  All Ages
# 4                                               R09.2  All Ages
# 5   J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 6                                             J09-J18  All Ages
# 7                                             J40-J47  All Ages
# 8                                                 J80  All Ages
# 9                                                 J96  All Ages
# 10                                              R09.2  All Ages
# 11  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 12                                            J09-J18  All Ages
# 13                                            J40-J47  All Ages
# 14                                                J80  All Ages
# 15                                                J96  All Ages
# 16                                              R09.2  All Ages
# 17  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 18                                            J09-J18  All Ages
# 19                                            J40-J47  All Ages
# 20                                                J80  All Ages
# 21                                                J96  All Ages
# 22                                              R09.2  All Ages
# 23  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 24                                            J09-J18  All Ages
# 25                                            J40-J47  All Ages
# 26                                                J80  All Ages
# 27                                                J96  All Ages
# 28                                              R09.2  All Ages
# 29  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 30                                            J09-J18  All Ages
# 31                                            J40-J47  All Ages
# 32                                                J80  All Ages
# 33                                                J96  All Ages
# 34                                              R09.2  All Ages
# 35  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 36                                            J09-J18  All Ages
# 37                                            J40-J47  All Ages
# 38                                                J80  All Ages
# 39                                                J96  All Ages
# 40                                              R09.2  All Ages
# 41  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 42                                            J09-J18  All Ages
# 43                                            J40-J47  All Ages
# 44                                                J80  All Ages
# 45                                                J96  All Ages
# 46                                              R09.2  All Ages
# 47  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 48                                            J09-J18  All Ages
# 49                                            J40-J47  All Ages
# 50                                                J80  All Ages
# 51                                                J96  All Ages
# 52                                              R09.2  All Ages
# 53  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
# 54                                            J09-J18  All Ages
# 55                                            J40-J47  All Ages
# 56                                                J80  All Ages
# 57                                                J96  All Ages
# 58                                              R09.2  All Ages
# 59  J00-J06, J20-J39, J60-J70, J81-J86, J90-J95, J...  All Ages
#
#     Number of COVID-19 Deaths Flag
# 0                      9098.0  NaN
# 1                      1187.0  NaN
# 2                      1902.0  NaN
# 3                      8056.0  NaN
# 4                       547.0  NaN
# 5                       622.0  NaN
# 6                      1007.0  NaN
# 7                       264.0  NaN
# 8                       567.0  NaN
# 9                       787.0  NaN
# 10                       17.0  NaN
# 11                      122.0  NaN
# 12                      917.0  NaN
# 13                      444.0  NaN
# 14                      270.0  NaN
# 15                     1611.0  NaN
# 16                      129.0  NaN
# 17                      428.0  NaN
# 18                     3168.0  NaN
# 19                      410.0  NaN
# 20                      642.0  NaN
# 21                     3184.0  NaN
# 22                      226.0  NaN
# 23                      318.0  NaN
# 24                     1552.0  NaN
# 25                      425.0  NaN
# 26                      490.0  NaN
# 27                     1044.0  NaN
# 28                       33.0  NaN
# 29                      171.0  NaN
# 30                      648.0  NaN
# 31                      291.0  NaN
# 32                      304.0  NaN
# 33                      663.0  NaN
# 34                       15.0  NaN
# 35                      116.0  NaN
# 36                      393.0  NaN
# 37                       64.0  NaN
# 38                      116.0  NaN
# 39                      235.0  NaN
# 40                       15.0  NaN
# 41                       36.0  NaN
# 42                     5467.0  NaN
# 43                      808.0  NaN
# 44                     2401.0  NaN
# 45                     3958.0  NaN
# 46                      379.0  NaN
# 47                      273.0  NaN
# 48                      199.0  NaN
# 49                       61.0  NaN
# 50                       58.0  NaN
# 51                      177.0  NaN
# 52                       12.0  NaN
# 53                       26.0  NaN
# 54                     1497.0  NaN
# 55                      299.0  NaN
# 56                      298.0  NaN
# 57                     1277.0  NaN
# 58                       31.0  NaN
# 59                      155.0  NaN

# %%
sum_lung = 0
for i in range(60):
    sum_lung = sum_lung + respiratory_all.iloc[i, 9]

sum_lung
# Out:
# 59910.0

# %%
C = US.loc[US['Condition Group'] == 'Circulatory diseases']
C_all = C.loc[C['Age Group'] == 'All Ages']
C_all = C_all.reset_index()
C_all
# Out:
#     index  Data as of  Start Week    End Week State       Condition Group  \
# 0    1209  11/04/2020  02/01/2020  10/31/2020    CA  Circulatory diseases
# 1    1219  11/04/2020  02/01/2020  10/31/2020    CA  Circulatory diseases
# 2    1229  11/04/2020  02/01/2020  10/31/2020    CA  Circulatory diseases
# 3    1239  11/04/2020  02/01/2020  10/31/2020    CA  Circulatory diseases
# 4    1249  11/04/2020  02/01/2020  10/31/2020    CA  Circulatory diseases
# ..    ...         ...         ...         ...   ...                   ...
# 65   9949  11/04/2020  02/01/2020  10/31/2020    TN  Circulatory diseases
# 66   9959  11/04/2020  02/01/2020  10/31/2020    TN  Circulatory diseases
# 67   9969  11/04/2020  02/01/2020  10/31/2020    TN  Circulatory diseases
# 68   9979  11/04/2020  02/01/2020  10/31/2020    TN  Circulatory diseases
# 69   9989  11/04/2020  02/01/2020  10/31/2020    TN  Circulatory diseases
#
#                                    Condition  \
# 0                      Hypertensive diseases
# 1                     Ischemic heart disease
# 2                             Cardiac arrest
# 3                         Cardiac arrhythmia
# 4                              Heart failure
# ..                                       ...
# 65                            Cardiac arrest
# 66                        Cardiac arrhythmia
# 67                             Heart failure
# 68                  Cerebrovascular diseases
# 69  Other diseases of the circulatory system
#
#                             ICD10_codes Age Group  Number of COVID-19 Deaths  \
# 0                               I10-I15  All Ages                     3423.0
# 1                               I20-I25  All Ages                     1878.0
# 2                                   I46  All Ages                     5059.0
# 3                     I44, I45, I47-I49  All Ages                     1159.0
# 4                                   I50  All Ages                     1107.0
# ..                                  ...       ...                        ...
# 65                                  I46  All Ages                      224.0
# 66                    I44, I45, I47-I49  All Ages                      205.0
# 67                                  I50  All Ages                      199.0
# 68                              I60-I69  All Ages                      201.0
# 69  I00-I09, I26-I43, I51, I52, I70-I99  All Ages                      229.0
#
#    Flag
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# ..  ...
# 65  NaN
# 66  NaN
# 67  NaN
# 68  NaN
# 69  NaN
#
# [70 rows x 11 columns]

# %%
sum_C = 0
for i in range(70):
    sum_C = sum_C + int(C_all.iloc[i, 9])

sum_C = sum_C
sum_C
# Out:
# 39111

# %%
S = US.loc[US['Condition Group'] == 'Sepsis']
S_all = S.loc[S['Age Group'] == 'All Ages']
S_all = S_all.reset_index()

S_all
# Out:
#    index  Data as of  Start Week    End Week State Condition Group Condition  \
# 0   1279  11/04/2020  02/01/2020  10/31/2020    CA          Sepsis    Sepsis
# 1   1509  11/04/2020  02/01/2020  10/31/2020    CO          Sepsis    Sepsis
# 2   1739  11/04/2020  02/01/2020  10/31/2020    CT          Sepsis    Sepsis
# 3   2639  11/04/2020  02/01/2020  10/31/2020    GA          Sepsis    Sepsis
# 4   4939  11/04/2020  02/01/2020  10/31/2020    MD          Sepsis    Sepsis
# 5   5629  11/04/2020  02/01/2020  10/31/2020    MN          Sepsis    Sepsis
# 6   7469  11/04/2020  02/01/2020  10/31/2020    NM          Sepsis    Sepsis
# 7   7699  11/04/2020  02/01/2020  10/31/2020    NY          Sepsis    Sepsis
# 8   8849  11/04/2020  02/01/2020  10/31/2020    OR          Sepsis    Sepsis
# 9   9999  11/04/2020  02/01/2020  10/31/2020    TN          Sepsis    Sepsis
#
#   ICD10_codes Age Group  Number of COVID-19 Deaths Flag
# 0     A40-A41  All Ages                     2725.0  NaN
# 1     A40-A41  All Ages                      180.0  NaN
# 2     A40-A41  All Ages                      289.0  NaN
# 3     A40-A41  All Ages                     1055.0  NaN
# 4     A40-A41  All Ages                      466.0  NaN
# 5     A40-A41  All Ages                      139.0  NaN
# 6     A40-A41  All Ages                       68.0  NaN
# 7     A40-A41  All Ages                      809.0  NaN
# 8     A40-A41  All Ages                       47.0  NaN
# 9     A40-A41  All Ages                      382.0  NaN

# %%
sum_S = 0
for i in range(10):
    sum_S = sum_S + S_all.iloc[i, 9]

sum_S
# Out:
# 6160.0

# %%
O = US.loc[US['Condition Group'] == 'Obesity']
O_all = O.loc[O['Age Group'] == 'All Ages']
O_all = O_all.reset_index()

O_all
# Out:
#    index  Data as of  Start Week    End Week State Condition Group Condition  \
# 0   1309  11/04/2020  02/01/2020  10/31/2020    CA         Obesity   Obesity
# 1   1539  11/04/2020  02/01/2020  10/31/2020    CO         Obesity   Obesity
# 2   1769  11/04/2020  02/01/2020  10/31/2020    CT         Obesity   Obesity
# 3   2669  11/04/2020  02/01/2020  10/31/2020    GA         Obesity   Obesity
# 4   4969  11/04/2020  02/01/2020  10/31/2020    MD         Obesity   Obesity
# 5   5659  11/04/2020  02/01/2020  10/31/2020    MN         Obesity   Obesity
# 6   7499  11/04/2020  02/01/2020  10/31/2020    NM         Obesity   Obesity
# 7   7729  11/04/2020  02/01/2020  10/31/2020    NY         Obesity   Obesity
# 8   8879  11/04/2020  02/01/2020  10/31/2020    OR         Obesity   Obesity
# 9  10029  11/04/2020  02/01/2020  10/31/2020    TN         Obesity   Obesity
#
#   ICD10_codes Age Group  Number of COVID-19 Deaths Flag
# 0     E65-E68  All Ages                      799.0  NaN
# 1     E65-E68  All Ages                       92.0  NaN
# 2     E65-E68  All Ages                       87.0  NaN
# 3     E65-E68  All Ages                      220.0  NaN
# 4     E65-E68  All Ages                      179.0  NaN
# 5     E65-E68  All Ages                       78.0  NaN
# 6     E65-E68  All Ages                       44.0  NaN
# 7     E65-E68  All Ages                      225.0  NaN
# 8     E65-E68  All Ages                       34.0  NaN
# 9     E65-E68  All Ages                      109.0  NaN

# %%
sum_O = 0
for i in range(10):
    sum_O = sum_O + O_all.iloc[i, 9]

sum_O
# Out:
# 1867.0

# %%
ND = US.loc[US['Condition Group'] == 'Alzheimer disease']
ND_all = ND.loc[ND['Age Group'] == 'All Ages']
ND_all = ND_all.reset_index()

ND1 = US.loc[US['Condition Group'] == 'Vascular and unspecified dementia']
ND1_all = ND1.loc[ND1['Age Group'] == 'All Ages']
ND1_all = ND1_all.reset_index()

print(ND_all, ND1_all)
# Out:
#    index  Data as of  Start Week    End Week State    Condition Group  \
# 0   1319  11/04/2020  02/01/2020  10/31/2020    CA  Alzheimer disease
# 1   1549  11/04/2020  02/01/2020  10/31/2020    CO  Alzheimer disease
# 2   1779  11/04/2020  02/01/2020  10/31/2020    CT  Alzheimer disease
# 3   2679  11/04/2020  02/01/2020  10/31/2020    GA  Alzheimer disease
# 4   4979  11/04/2020  02/01/2020  10/31/2020    MD  Alzheimer disease
# 5   5669  11/04/2020  02/01/2020  10/31/2020    MN  Alzheimer disease
# 6   7509  11/04/2020  02/01/2020  10/31/2020    NM  Alzheimer disease
# 7   7739  11/04/2020  02/01/2020  10/31/2020    NY  Alzheimer disease
# 8   8889  11/04/2020  02/01/2020  10/31/2020    OR  Alzheimer disease
# 9  10039  11/04/2020  02/01/2020  10/31/2020    TN  Alzheimer disease
#
#            Condition ICD10_codes Age Group  Number of COVID-19 Deaths Flag
# 0  Alzheimer disease         G30  All Ages                      955.0  NaN
# 1  Alzheimer disease         G30  All Ages                      154.0  NaN
# 2  Alzheimer disease         G30  All Ages                      139.0  NaN
# 3  Alzheimer disease         G30  All Ages                      266.0  NaN
# 4  Alzheimer disease         G30  All Ages                      103.0  NaN
# 5  Alzheimer disease         G30  All Ages                      259.0  NaN
# 6  Alzheimer disease         G30  All Ages                       27.0  NaN
# 7  Alzheimer disease         G30  All Ages                      254.0  NaN
# 8  Alzheimer disease         G30  All Ages                       55.0  NaN
# 9  Alzheimer disease         G30  All Ages                      105.0  NaN      index  Data as of  Start Week    End Week State  \
# 0   1329  11/04/2020  02/01/2020  10/31/2020    CA
# 1   1559  11/04/2020  02/01/2020  10/31/2020    CO
# 2   1789  11/04/2020  02/01/2020  10/31/2020    CT
# 3   2689  11/04/2020  02/01/2020  10/31/2020    GA
# 4   4989  11/04/2020  02/01/2020  10/31/2020    MD
# 5   5679  11/04/2020  02/01/2020  10/31/2020    MN
# 6   7519  11/04/2020  02/01/2020  10/31/2020    NM
# 7   7749  11/04/2020  02/01/2020  10/31/2020    NY
# 8   8899  11/04/2020  02/01/2020  10/31/2020    OR
# 9  10049  11/04/2020  02/01/2020  10/31/2020    TN
#
#                      Condition Group                          Condition  \
# 0  Vascular and unspecified dementia  Vascular and unspecified dementia
# 1  Vascular and unspecified dementia  Vascular and unspecified dementia
# 2  Vascular and unspecified dementia  Vascular and unspecified dementia
# 3  Vascular and unspecified dementia  Vascular and unspecified dementia
# 4  Vascular and unspecified dementia  Vascular and unspecified dementia
# 5  Vascular and unspecified dementia  Vascular and unspecified dementia
# 6  Vascular and unspecified dementia  Vascular and unspecified dementia
# 7  Vascular and unspecified dementia  Vascular and unspecified dementia
# 8  Vascular and unspecified dementia  Vascular and unspecified dementia
# 9  Vascular and unspecified dementia  Vascular and unspecified dementia
#
#   ICD10_codes Age Group  Number of COVID-19 Deaths Flag
# 0    F01, F03  All Ages                     1258.0  NaN
# 1    F01, F03  All Ages                      396.0  NaN
# 2    F01, F03  All Ages                      785.0  NaN
# 3    F01, F03  All Ages                      538.0  NaN
# 4    F01, F03  All Ages                      912.0  NaN
# 5    F01, F03  All Ages                      628.0  NaN
# 6    F01, F03  All Ages                       75.0  NaN
# 7    F01, F03  All Ages                     1228.0  NaN
# 8    F01, F03  All Ages                      111.0  NaN
# 9    F01, F03  All Ages                      303.0  NaN

# %%
sum_ND = 0
for i in range(10):
    sum_ND = sum_ND + ND_all.iloc[i, 9]

sum_ND1 = 0
for i in range(10):
    sum_ND1 = sum_ND1 + ND1_all.iloc[i, 9]

sum_ND = sum_ND + sum_ND1
sum_ND
# Out:
# 8551.0

# %%
R = US.loc[US['Condition Group'] == 'Renal failure']
R_all = R.loc[R['Age Group'] == 'All Ages']
R_all = R_all.reset_index()
R_all
# Out:
#    index  Data as of  Start Week    End Week State Condition Group  \
# 0   1339  11/04/2020  02/01/2020  10/31/2020    CA   Renal failure
# 1   1569  11/04/2020  02/01/2020  10/31/2020    CO   Renal failure
# 2   1799  11/04/2020  02/01/2020  10/31/2020    CT   Renal failure
# 3   2699  11/04/2020  02/01/2020  10/31/2020    GA   Renal failure
# 4   4999  11/04/2020  02/01/2020  10/31/2020    MD   Renal failure
# 5   5689  11/04/2020  02/01/2020  10/31/2020    MN   Renal failure
# 6   7529  11/04/2020  02/01/2020  10/31/2020    NM   Renal failure
# 7   7759  11/04/2020  02/01/2020  10/31/2020    NY   Renal failure
# 8   8909  11/04/2020  02/01/2020  10/31/2020    OR   Renal failure
# 9  10059  11/04/2020  02/01/2020  10/31/2020    TN   Renal failure
#
#        Condition ICD10_codes Age Group  Number of COVID-19 Deaths Flag
# 0  Renal failure     N17-N19  All Ages                     2149.0  NaN
# 1  Renal failure     N17-N19  All Ages                      252.0  NaN
# 2  Renal failure     N17-N19  All Ages                      305.0  NaN
# 3  Renal failure     N17-N19  All Ages                      677.0  NaN
# 4  Renal failure     N17-N19  All Ages                      608.0  NaN
# 5  Renal failure     N17-N19  All Ages                      208.0  NaN
# 6  Renal failure     N17-N19  All Ages                       61.0  NaN
# 7  Renal failure     N17-N19  All Ages                      872.0  NaN
# 8  Renal failure     N17-N19  All Ages                       53.0  NaN
# 9  Renal failure     N17-N19  All Ages                      319.0  NaN

# %%
sum_R = 0
for i in range(10):
    sum_R = sum_R + R_all.iloc[i, 9]
    
sum_R
# Out:
# 5504.0

# %% [markdown]
# Hospitalisation data

# %%
pwd
# Out:
# '/Users/xpeng/Downloads'

# %%
cd /Users/xpeng/Downloads
# Out:
# /Users/xpeng/Downloads

# %%
Filename = 'Medical_Conditions.csv'
data = pd.read_csv(Filename, skiprows = 2, encoding = "ISO-8859-1")
DATA = data.iloc[:-3].drop(columns = ['YEAR','FEMALES (15-44 YR)-COUNT','FEMALES (15-44 YR)-PERCENT(%)', 'ADULTS-COUNT'])
DATA
# Out:
#                  MEDICAL CONDITION  CHILDREN-COUNT  CHILDREN-PERCENT(%)  \
# 0                           Asthma            35.0                 13.2
# 1           Cardiovascular disease             8.0                  3.0
# 2             Chronic lung disease            17.0                  6.4
# 3               Immune suppression            14.0                  5.3
# 4                Metabolic disease            14.0                  5.3
# 5               Neurologic disease            34.0                 12.8
# 6                    Other disease            51.0                 19.2
# 7               No known condition           130.0                 49.1
# 8              Autoimmune disease              1.0                  0.4
# 9                          Obesity            51.0                 43.2
# 10                       Pregnancy             NaN                  NaN
# 11                   Renal disease             NaN                  NaN
# 12  Gastrointestinal/liver disease             3.0                  1.1
# 13                    Hypertension             5.0                  1.9
#
#     ADULTS-PERCENT(%)
# 0                10.7
# 1                34.3
# 2                19.3
# 3                 8.8
# 4                42.9
# 5                24.7
# 6                 9.9
# 7                 9.4
# 8                 2.9
# 9                46.1
# 10                NaN
# 11               16.3
# 12                4.6
# 13               59.1

# %%
population_data = pd.read_csv('COVID-19Surveillance_All_Data.csv', skiprows = 2, encoding = "ISO-8859-1")
population_data = population_data.iloc[0:33252].drop(columns = ['MMWR-YEAR', 'YEAR'])
cumulative_rate = population_data.iloc[4767, 6]
children_rate = population_data.iloc[31604, 6]
adult_rate = population_data.iloc[33239, 6]

# %%
percentage_cumulative = (cumulative_rate/100000)*328.2*10**6*0.03
percentage_cumulative.round()
# Out:
# 21809.0

# %%
percentage_children = (children_rate/100000)
no_C = percentage_children*73039150*0.03
no_C.round()
# Out:
# 355.0

# %%
percentage_adult = (adult_rate/100000)
no_A = percentage_adult*255200373*0.03
no_A.round()
# Out:
# 21406.0

# %%
percentage_obesity = DATA.iloc[9,2]
Obesity_C = (percentage_obesity*no_C).round()

percentage_obesity = DATA.iloc[9,3]
Obesity_A = (percentage_obesity*no_A).round()

list_O = [Obesity_A, Obesity_C]

# %%
percentage_renal = DATA.iloc[11,3]
Renal_A = (percentage_renal*no_A).round()

list_R = [Renal_A, '-']

# %%
percentage_asthma = DATA.iloc[0,2]
Asthma_C = percentage_asthma*no_C

percentage_Asthma = DATA.iloc[0,3]
Asthma_A = percentage_asthma*no_A

percentage_lung = DATA.iloc[2,2]
Lung_C = (percentage_lung*no_C + Asthma_C).round()


percentage_lung = DATA.iloc[2,3]
Lung_A = (percentage_lung*no_A + Asthma_A).round()

list_L = [Lung_A, Lung_C]

# %%
percentage_AI = DATA.iloc[8,2]
AI_C = percentage_AI*no_C

percentage_AI = DATA.iloc[8,3]
AI_A = percentage_AI*no_A


percentage_IS = DATA.iloc[3,2]
IS_C = (percentage_IS*no_C + AI_C).round()

percentage_obesity = DATA.iloc[3,3]
IS_A = (percentage_IS*no_A + AI_A).round()

list_IS = [IS_A, IS_C]

# %%
percentage_ND = DATA.iloc[5,2]
ND_C = (percentage_ND*no_C).round()

percentage_ND = DATA.iloc[5,3]
ND_A = (percentage_ND*no_A).round()

list_ND = [ND_A, ND_C]

# %%
percentage_H = DATA.iloc[13,2]
H_C = percentage_H*no_C

percentage_H = DATA.iloc[13,3]
H_A = percentage_H*no_A


percentage_CV = DATA.iloc[1,2]
CV_C = (percentage_CV*no_C + H_C).round()

percentage_CV = DATA.iloc[1,3]
CV_A = (percentage_CV*no_A + H_A).round()


list_CV = [CV_A, CV_C]

# %%
medical_conditions = ['Respiratory', 'Circulatory', 'Immune related', 'Obesity', 'Neurological', 'Renal']
Adult_no = [Lung_A, CV_A, IS_A, Obesity_A, ND_A, Renal_A]
Children_no = [Lung_C, CV_C, IS_C, Obesity_C, ND_C, 0]
df = pd.DataFrame(list(zip(medical_conditions, Adult_no, Children_no)), columns =['Conditions','Adult', 'Children'])
df = df.set_index('Conditions')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 15))
plt.bar(medical_conditions, Adult_no, label='Adult')
plt.bar(medical_conditions, Children_no, label = 'Children')
plt.legend()
plt.xlabel('Conditions')
plt.ylabel('Number of cases')
# Out:
# Text(0, 0.5, 'Number of cases')

# %%
new_list = []
for i in range(len(Adult_no)):
    new_no = Adult_no[i] + Children_no[i]
    new_list.append(new_no)
    
plt.figure(figsize=(9, 10))
plt.bar(medical_conditions, new_list, label='Total')
plt.legend()
plt.xlabel('Conditions')
plt.ylabel('Number of cases')
# Out:
# Text(0, 0.5, 'Number of cases')

# %%
Adult_no = Lung_A +CV_A+ IS_A+ Obesity_A+ ND_A+Renal_A
Children_no = Lung_C+ CV_C+ IS_C+ Obesity_C+ ND_C
Y = Adult_no+ Children_no
print(Y)
# Out:
# 4765651.0

# %% [markdown]
# Fatality rates

# %%
#lung 
rate_lung = (sum_lung/(Lung_A+Lung_C))*100
rate_lung
# Out:
# 8.526184109219408

# %%
#cardiovascular/ heart related
rate_CV = (sum_C/(CV_A+CV_C))*100
rate_CV
# Out:
# 1.9544955496509635

# %%
#Autoimmune systems related
rate_IS= (sum_S/(IS_A+IS_C))*100
rate_IS
# Out:
# 3.4693670657940685

# %%
#Obesity
rate_O = (sum_O/(Obesity_A+Obesity_C))*100
rate_O
# Out:
# 0.18629741129419325

# %%
#Neurological diseases 
rate_ND = (sum_ND/(ND_A+ND_C))*100
rate_ND
# Out:
# 1.6034818677722835

# %%
#Renal 
rate_R = (sum_R/Renal_A)*100
rate_R
# Out:
# 1.5774344335823869

# %%
Rate = [rate_lung, rate_CV, rate_IS, rate_O, rate_ND, rate_R]
plt.figure(figsize=(9, 15))
plt.bar(medical_conditions, Rate, label='Fatality rates')
plt.legend()
plt.xlabel('Conditions')
plt.ylabel('Fatality rates')
# Out:
# Text(0, 0.5, 'Fatality rates')
